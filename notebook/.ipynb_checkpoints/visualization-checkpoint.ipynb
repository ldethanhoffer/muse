# %%
import os
os.chdir("..")
import muse
# Out:
# Using TensorFlow backend.

# %%
muse.main()
# Out:
# Loading VGG19 pre-trained model...
# /Users/Louis/muse/muse.py:39: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("bl...)`
#   output=base_model.get_layer('block4_pool').output)
# Reading the images from 'data/final' directory...
#
# imgs.shape = (192, 224, 224, 3)
# X_features.shape = (192, 100352)
#
# [1/192] finding your recommendations: e1
# [2/192] finding your recommendations: e10
# [3/192] finding your recommendations: e11
# [4/192] finding your recommendations: e12
# [5/192] finding your recommendations: e13
# [6/192] finding your recommendations: e14
# [7/192] finding your recommendations: e15
# [8/192] finding your recommendations: e16
# [9/192] finding your recommendations: e17
# [10/192] finding your recommendations: e18
# [11/192] finding your recommendations: e19
# [12/192] finding your recommendations: e2
# [13/192] finding your recommendations: e20
# [14/192] finding your recommendations: e21
# ...

# %%
muse.recommend("20th century", "1")

# %%
import random

# %%
l = [] 
for x in random.randint(1,21):
    l.append(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-c031bd2d9a07> in <module>
#       1 l = []
# ----> 2 for x in random.randint(1,21):
#       3     l.append(x)
#
# TypeError: 'int' object is not iterable

# %%
l
# Out:
# []

# %%
l = random.rand(xrange(100),10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-88a1929e19ea> in <module>
# ----> 1 l = random.sample(xrange(100),10)
#
# NameError: name 'xrange' is not defined

# %%
my_randoms = [random.randrange(1, 400) for _ in range(4)]

# %%
print(my_randoms)
# Out:
# [56, 159, 222, 159]

# %%
muse.get_recommendations()
# Out:
# Loading the VGG19 model
# /Users/Louis/muse/muse.py:122: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("bl...)`
#   output=base_model.get_layer('block4_pool').output)
# Reading the images from 'data/final' directory...
#
# imgs.shape = (192, 224, 224, 3)
# X_features.shape = (192, 100352)
#
# [1/192] finding your recommendations: e1
# [2/192] finding your recommendations: e10
# [3/192] finding your recommendations: e11
# [4/192] finding your recommendations: e12
# [5/192] finding your recommendations: e13
# [6/192] finding your recommendations: e14
# [7/192] finding your recommendations: e15
# [8/192] finding your recommendations: e16
# [9/192] finding your recommendations: e17
# [10/192] finding your recommendations: e18
# [11/192] finding your recommendations: e19
# [12/192] finding your recommendations: e2
# [13/192] finding your recommendations: e20
# [14/192] finding your recommendations: e21
# ...

# %%
import numpy as np

# %%
a =np.array([1,2,3,4])

# %%
a[1:2]
# Out:
# array([2])

# %%
r = np.array([random.randrange(1, 400) for _ in range(4)])

# %%
import random

# %%
a+r
# Out:
# array([195, 330, 246, 295])

# %%
r
# Out:
# array([194, 328, 243, 291])

# %%
np.concatenate((a,r))
# Out:
# array([  1,   2,   3,   4, 194, 328, 243, 291])

# %%
d = {'e1':['e1','e10'],'e2':['e2','e20']}

# %%
for item in d:
    i=0
    or_movement = item[0]
    suggested_movement  = d[item][0][0]
    if or_movement == suggested_movement:
        i = i+1
# Out:
# e e
# e e

# %%
len(d)
# Out:
# 2
