# %%
import os
os.chdir("..")
import muse
# Out:
# Using TensorFlow backend.

# %%
muse.main()
# Out:
# Loading VGG19 pre-trained model...
# /Users/Louis/muse/muse.py:30: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("bl...)`
#   output=base_model.get_layer('block4_pool').output)
# Reading the images from 'data/raw' directory...
#
# imgs.shape = (22, 224, 224, 3)
# X_features.shape = (22, 100352)
#
# [1/22] You may also like the following paintings: iconic 20th century paintings-10
# [2/22] You may also like the following paintings: iconic 20th century paintings-11
# [3/22] You may also like the following paintings: iconic 20th century paintings-12
# [4/22] You may also like the following paintings: iconic 20th century paintings-13
# [5/22] You may also like the following paintings: iconic 20th century paintings-14
# [6/22] You may also like the following paintings: iconic 20th century paintings-15
# [7/22] You may also like the following paintings: iconic 20th century paintings-16
# ...
