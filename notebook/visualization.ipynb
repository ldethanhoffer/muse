# %%
import os
os.chdir("..")
import muse
# Out:
# Using TensorFlow backend.

# %%
muse.main()
# Out:
# Loading VGG19 pre-trained model...
# /Users/Louis/muse/muse.py:33: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("bl...)`
#   output=base_model.get_layer('block4_pool').output)
# Reading the images from 'data/raw' directory...
#
# imgs.shape = (10, 224, 224, 3)
# X_features.shape = (10, 100352)
#
# [1/10] finding your recommendations: iconic 20th century paintings-1
# [2/10] finding your recommendations: iconic 20th century paintings-10
# [3/10] finding your recommendations: iconic 20th century paintings-11
# [4/10] finding your recommendations: iconic 20th century paintings-12
# [5/10] finding your recommendations: iconic 20th century paintings-2
# [6/10] finding your recommendations: iconic 20th century paintings-4
# [7/10] finding your recommendations: iconic 20th century paintings-6
# [8/10] finding your recommendations: iconic 20th century paintings-7
# [9/10] finding your recommendations: iconic 20th century paintings-8
# ...

# %%
muse.recommend("20th century", "1")

# %%
import random

# %%
l = [] 
for x in random.randint(1,21):
    l.append(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-c031bd2d9a07> in <module>
#       1 l = []
# ----> 2 for x in random.randint(1,21):
#       3     l.append(x)
#
# TypeError: 'int' object is not iterable

# %%
l
# Out:
# []

# %%
l = random.rand(xrange(100),10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-88a1929e19ea> in <module>
# ----> 1 l = random.sample(xrange(100),10)
#
# NameError: name 'xrange' is not defined

# %%
my_randoms = [random.randrange(1, 400) for _ in range(4)]

# %%
print(my_randoms)
# Out:
# [56, 159, 222, 159]
