# %%
import os
os.chdir("..")

# %%
import muse
# Out:
# Using TensorFlow backend.

# %%
muse.main()
# Out:
# Loading VGG19 pre-trained model...
# Reading images from 'db_1' directory...
#
# imgs.shape = (15, 224, 224, 3)
# X_features.shape = (15, 100352)
#
# [1/15] Plotting similar image recommendations for: iconic 20th century paintings-1
# [2/15] Plotting similar image recommendations for: iconic 20th century paintings-10
# [3/15] Plotting similar image recommendations for: iconic 20th century paintings-11
# [4/15] Plotting similar image recommendations for: iconic 20th century paintings-12
# [5/15] Plotting similar image recommendations for: iconic 20th century paintings-13
# [6/15] Plotting similar image recommendations for: iconic 20th century paintings-14
# [7/15] Plotting similar image recommendations for: iconic 20th century paintings-15
# [8/15] Plotting similar image recommendations for: iconic 20th century paintings-16
# [9/15] Plotting similar image recommendations for: iconic 20th century paintings-17
# ...
